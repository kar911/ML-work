# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as pl

# %%
df=pd.read_csv("data/survey_results_public.csv")

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
# ...

# %%
df.describe()
# Out:
#          Respondent           Age      CompTotal  ConvertedComp   WorkWeekHrs
# count  64461.000000  45446.000000   3.482600e+04   3.475600e+04  41151.000000
# mean   32554.079738     30.834111  3.190464e+242   1.037561e+05     40.782174
# std    18967.442360      9.585392            inf   2.268853e+05     17.816383
# min        1.000000      1.000000   0.000000e+00   0.000000e+00      1.000000
# 25%    16116.000000     24.000000   2.000000e+04   2.464800e+04     40.000000
# 50%    32231.000000     29.000000   6.300000e+04   5.404900e+04     40.000000
# 75%    49142.000000     35.000000   1.250000e+05   9.500000e+04     44.000000
# max    65639.000000    279.000000  1.111111e+247   2.000000e+06    475.000000

# %%
c=df["Country"].value_counts()

# %%
c[c > 300].std()
# Out:
# 2237.235928353124

# %%
import seaborn as sn

# %% [markdown]
# ## filtering

# %%
f=(df["CurrencyDesc"].str.contains("rupee"))
df.dropna()
# Out:
#        Respondent                      MainBranch Hobbyist   Age Age1stCode  \
# 9              10  I am a developer by profession      Yes  22.0         14
# 32             33  I am a developer by profession      Yes  39.0         14
# 41             42  I am a developer by profession       No  32.0         14
# 46             47  I am a developer by profession      Yes  53.0         10
# 68             69  I am a developer by profession      Yes  25.0         12
# ...           ...                             ...      ...   ...        ...
# 61613       62863  I am a developer by profession      Yes  30.0         11
# 61636       62886  I am a developer by profession      Yes  32.0         24
# 61654       62904  I am a developer by profession      Yes  33.0         24
# 61993       63288  I am a developer by profession       No  31.0         16
# 63517       64938  I am a developer by profession       No  33.0         13
#
# ...

# %%
df[df["CurrencyDesc"] .str.contains("rupee",na=False)]
# Out:
#        Respondent                      MainBranch Hobbyist   Age Age1stCode  \
# 21             22  I am a developer by profession      Yes   NaN         18
# 57             58  I am a developer by profession      Yes   NaN         22
# 147           149  I am a developer by profession      Yes  36.0         31
# 171           173  I am a developer by profession      Yes  26.0         13
# 175           177  I am a developer by profession      Yes   NaN         18
# ...           ...                             ...      ...   ...        ...
# 64048       65517  I am a developer by profession      Yes   NaN         15
# 64053       65523  I am a developer by profession      Yes   NaN         18
# 64071       65541  I am a developer by profession      Yes   NaN         13
# 64111       65584  I am a developer by profession      Yes   NaN         19
# 64117       65590  I am a developer by profession      Yes   NaN         21
#
# ...

# %%
df[ df.Country == "India" ]
# Out:
#        Respondent                              MainBranch Hobbyist   Age  \
# 6               7          I am a developer by profession      Yes   NaN
# 21             22          I am a developer by profession      Yes   NaN
# 57             58          I am a developer by profession      Yes   NaN
# 62             63  I am a student who is learning to code      Yes  21.0
# 147           149          I am a developer by profession      Yes  36.0
# ...           ...                                     ...      ...   ...
# 64391       54757                                     NaN      Yes   NaN
# 64398       55407                                     NaN      Yes   NaN
# 64439       62464                                     NaN      Yes   NaN
# 64442       62954                                     NaN      Yes   NaN
# 64452       64236                                     NaN      Yes   NaN
#
#       Age1stCode CompFreq   CompTotal  ConvertedComp Country  \
# ...

# %%
df[df.ConvertedComp > 70000].shape
# Out:
# (13178, 61)

# %%
df.shape
# Out:
# (64461, 61)

# %%
c=df.where(df["Country"] == "India")

# %%
c.dropna()
# Out:
#        Respondent                      MainBranch Hobbyist   Age Age1stCode  \
# 622         624.0  I am a developer by profession      Yes  26.0         16
# 2042       2051.0  I am a developer by profession      Yes  28.0          7
# 3218       3232.0  I am a developer by profession      Yes  24.0         13
# 3635       3650.0  I am a developer by profession      Yes  25.0         18
# 5737       5761.0  I am a developer by profession      Yes  25.0         15
# ...           ...                             ...      ...   ...        ...
# 57281     58408.0  I am a developer by profession      Yes  23.0         18
# 58697     59856.0  I am a developer by profession      Yes  24.0         19
# 59524     60703.0  I am a developer by profession      Yes  28.0         17
# 60727     61950.0  I am a developer by profession      Yes  45.0         15
# 60885     62113.0  I am a developer by profession      Yes  33.0         10
#
# ...

# %%
df.columns=[ i if i != "Respondent" else "res" for i in df.columns ]

# %%
df.columns
# Out:
# Index(['res', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
b=df.head(2)
# b[type(b.index) == 'obj'].applymap(str.lower)

# %%
# b[ b.Dtype == 'obj' ]

# %%
df["Hobbyist"].map({"Yes":True,"No":False})
# Out:
# 0         True
# 1        False
# 2         True
# 3         True
# 4         True
#          ...
# 64456     True
# 64457     True
# 64458     True
# 64459     True
# 64460     True
# Name: Hobbyist, Length: 64461, dtype: object

# %%
df.Hobbyist
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3        Yes
# 4        Yes
#         ...
# 64456    Yes
# 64457    Yes
# 64458    Yes
# 64459    Yes
# 64460    Yes
# Name: Hobbyist, Length: 64461, dtype: object

# %%
# df.xs()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [21], in <module>
# ----> 1 df.xs()
#
# TypeError: xs() missing 1 required positional argument: 'key'

# %%
d = {'num_legs': [4, 4, 2, 2],
'num_wings': [0, 0, 2, 2],
'class': ['mammal', 'mammal', 'mammal', 'bird'],
'animal': ['cat', 'dog', 'bat', 'penguin']}
df1 = pd.DataFrame(data=d)
df1 = df1.set_index(['class', 'animal'])

# %%
df1
# Out:
#                 num_legs  num_wings
# class  animal
# mammal cat             4          0
#        dog             4          0
#        bat             2          2
# bird   penguin         2          2

# %%
df1.xs(key="bird")
# Out:
#          num_legs  num_wings
# animal
# penguin         2          2

# %%
df["CurrencyDesc"].str.split(" ",expand=True)
# df.CurrencyDesc.str.split()
# Out:
#               0         1     2     3     4
# 0      European      Euro  None  None  None
# 1         Pound  sterling  None  None  None
# 2           NaN       NaN   NaN   NaN   NaN
# 3      Albanian       lek  None  None  None
# 4           NaN       NaN   NaN   NaN   NaN
# ...         ...       ...   ...   ...   ...
# 64456       NaN       NaN   NaN   NaN   NaN
# 64457       NaN       NaN   NaN   NaN   NaN
# 64458       NaN       NaN   NaN   NaN   NaN
# 64459       NaN       NaN   NaN   NaN   NaN
# 64460       NaN       NaN   NaN   NaN   NaN
#
# [64461 rows x 5 columns]

# %%
df.append({"CurrencyDesc":"ininkdf"},ignore_index=True).tail(5)
# Out:
# /tmp/ipykernel_3726/4130189855.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append({"CurrencyDesc":"ininkdf"},ignore_index=True).tail(5)
#            res MainBranch Hobbyist  Age Age1stCode CompFreq  CompTotal  \
# 64457  64867.0        NaN      Yes  NaN        NaN      NaN        NaN
# 64458  64898.0        NaN      Yes  NaN        NaN      NaN        NaN
# 64459  64925.0        NaN      Yes  NaN        NaN      NaN        NaN
# 64460  65112.0        NaN      Yes  NaN        NaN      NaN        NaN
# 64461      NaN        NaN      NaN  NaN        NaN      NaN        NaN
#
#        ConvertedComp   Country CurrencyDesc  ... SurveyEase SurveyLength  \
# 64457            NaN   Morocco          NaN  ...        NaN          NaN
# 64458            NaN  Viet Nam          NaN  ...        NaN          NaN
# 64459            NaN    Poland          NaN  ...        NaN          NaN
# ...

# %%
df.dropna(axis=0,thresh=61).shape
# Out:
# (4213, 61)

# %%
df.dropna().shape
# Out:
# (4213, 61)

# %%
g=list()
for i in range(df.shape[1]):
    g.append(df.iloc[:,i].isnull().value_counts())

# %%
x=pd.concat(g,axis=1)

# %%
x=x.transpose()

# %%
x.rename(columns={False:"False",True:"True"},inplace=True)

# %%
x.sort_values(by=["False","True"],ascending=[False,True])
# Out:
#                           False     True
# res                     64461.0      NaN
# Hobbyist                64416.0     45.0
# MainBranch              64162.0    299.0
# Country                 64072.0    389.0
# Employment              63854.0    607.0
# ...                         ...      ...
# WebframeDesireNextYear  40024.0  24437.0
# PurchaseWhat            39364.0  25097.0
# NEWPurchaseResearch     37321.0  27140.0
# CompTotal               34826.0  29635.0
# ConvertedComp           34756.0  29705.0
#
# [61 rows x 2 columns]

# %%
x["True"].nlargest(10)
# Out:
# ConvertedComp             29705.0
# CompTotal                 29635.0
# NEWPurchaseResearch       27140.0
# PurchaseWhat              25097.0
# WebframeDesireNextYear    24437.0
# CompFreq                  24392.0
# MiscTechWorkedWith        24147.0
# NEWJobHuntResearch        23439.0
# WorkWeekHrs               23310.0
# NEWDevOpsImpt             22729.0
# Name: True, dtype: float64

# %%
df[(df["CompFreq"] == "Weekly") & (df.Country == "India") ].nlargest(5,"ConvertedComp")
# Out:
#          res                                         MainBranch Hobbyist  \
# 21268  21351                     I am a developer by profession       No
# 42311  43053                     I am a developer by profession      Yes
# 49324  50343  I am not primarily a developer, but I write co...      Yes
# 53764  54859                     I am a developer by profession       No
# 45843  46805                     I am a developer by profession       No
#
#         Age            Age1stCode CompFreq     CompTotal  ConvertedComp  \
# 21268  98.0                    17   Weekly  8.988829e+30      1000000.0
# 42311   NaN  Younger than 5 years   Weekly  7.852931e+09      1000000.0
# 49324   NaN                    18   Weekly  1.000000e+36      1000000.0
# 53764  26.0                    20   Weekly  5.000000e+06      1000000.0
# 45843   NaN                    23   Weekly  7.000000e+05       488650.0
#
#       Country    CurrencyDesc  ...                  SurveyEase  \
# ...

# %% [markdown]
# ## nsmallest and nlargest

# %%
df[(df["CompFreq"] == "Weekly") & (df.Country == "India") ].nsmallest(5,"ConvertedComp")
# Out:
#          res                      MainBranch Hobbyist   Age Age1stCode  \
# 5785    5809  I am a developer by profession      Yes   NaN         15
# 6163    6188  I am a developer by profession      Yes   NaN         15
# 21202  21285  I am a developer by profession      Yes  27.0          5
# 27838  27942  I am a developer by profession      Yes   NaN         18
# 37051  37342  I am a developer by profession      Yes   NaN         16
#
#       CompFreq  CompTotal  ConvertedComp Country   CurrencyDesc  ...  \
# 5785    Weekly       10.0            0.0   India   Indian rupee  ...
# 6163    Weekly        0.0            0.0   India   Indian rupee  ...
# 21202   Weekly        8.0            0.0   India  Armenian dram  ...
# 27838   Weekly        0.0            0.0   India   Indian rupee  ...
# 37051   Weekly        7.0            0.0   India   Indian rupee  ...
#
#                        SurveyEase           SurveyLength Trans  \
# ...

# %%
df.select_dtypes("object")
# Out:
#                                               MainBranch Hobbyist Age1stCode  \
# 0                         I am a developer by profession      Yes         13
# 1                         I am a developer by profession       No         19
# 2                            I code primarily as a hobby      Yes         15
# 3                         I am a developer by profession      Yes         18
# 4      I used to be a developer by profession, but no...      Yes         16
# ...                                                  ...      ...        ...
# 64456                                                NaN      Yes         16
# 64457                                                NaN      Yes        NaN
# 64458                                                NaN      Yes        NaN
# 64459                                                NaN      Yes        NaN
# 64460                                                NaN      Yes        NaN
#
# ...

# %%
df.groupby("Country").sum()
# Out:
#                                            res     Age     CompTotal  \
# Country
# Afghanistan                            3129142   518.0  1.427182e+10
# Albania                                1838295   803.0  2.247393e+06
# Algeria                                3654080  1429.0  1.158900e+06
# Andorra                                 536399   117.0  1.640000e+05
# Angola                                  350473   120.0  2.374040e+05
# ...                                        ...     ...           ...
# Venezuela, Bolivarian Republic of...   2645909  1624.0  7.032049e+07
# Viet Nam                              13530046  4234.0  4.958551e+16
# Yemen                                   339895    62.0  3.000000e+03
# Zambia                                  900892   282.0  1.120000e+05
# Zimbabwe                               1058845   486.0  5.211000e+04
#
#                                       ConvertedComp  WorkWeekHrs
# Country
# ...

# %%
f=df.groupby("Country")
df.Age1stCode
# Out:
# 0         13
# 1         19
# 2         15
# 3         18
# 4         16
#         ...
# 64456     16
# 64457    NaN
# 64458    NaN
# 64459    NaN
# 64460    NaN
# Name: Age1stCode, Length: 64461, dtype: object

# %%
f.get_group("India")["Age1stCode"].value_counts().head(50)
# Out:
# 18                      1140
# 16                       839
# 17                       802
# 15                       586
# 19                       585
# 20                       537
# 14                       420
# 12                       307
# 21                       280
# 13                       273
# 22                       220
# 10                       175
# 23                       130
# 11                       101
# 24                        96
# 25                        71
# 9                         54
# Younger than 5 years      49
# 8                         45
# 5                         45
# 7                         35
# 26                        27
# 6                         22
# 27                        21
# 28                        11
# 30                         7
# 32                         6
# 29                         6
# 35                         3
# 31                         2
# 36                         2
# 40                         2
# ...

# %%
df.columns
# Out:
# Index(['res', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
f["SOAccount"].value_counts().loc["India"]
# Out:
# SOAccount
# Yes                        5920
# No                          471
# Not sure/can't remember     367
# Name: SOAccount, dtype: int64

# %%
f["SOAccount"].value_counts(normalize=True).loc["India"]
# Out:
# SOAccount
# Yes                        0.875999
# No                         0.069695
# Not sure/can't remember    0.054306
# Name: SOAccount, dtype: float64

# %%
df.head()
# Out:
#    res                                         MainBranch Hobbyist   Age  \
# 0    1                     I am a developer by profession      Yes   NaN
# 1    2                     I am a developer by profession       No   NaN
# 2    3                        I code primarily as a hobby      Yes   NaN
# 3    4                     I am a developer by profession      Yes  25.0
# 4    5  I used to be a developer by profession, but no...      Yes  31.0
#
#   Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0         13  Monthly        NaN            NaN             Germany
# 1         19      NaN        NaN            NaN      United Kingdom
# 2         15      NaN        NaN            NaN  Russian Federation
# 3         18      NaN        NaN            NaN             Albania
# 4         16      NaN        NaN            NaN       United States
#
#      CurrencyDesc  ...                  SurveyEase           SurveyLength  \
# ...

# %%
# .groupby(['Sex','Survived'])['Survived'].count()
f=df.isnull().sum().reset_index()
f.sort_values(by=0,ascending=False)
# Out:
#                      index      0
# 7            ConvertedComp  29705
# 6                CompTotal  29635
# 37     NEWPurchaseResearch  27140
# 45            PurchaseWhat  25097
# 55  WebframeDesireNextYear  24437
# ..                     ...    ...
# 15              Employment    607
# 8                  Country    389
# 1               MainBranch    299
# 2                 Hobbyist     45
# 0                      res      0
#
# [61 rows x 2 columns]

# %%
data=pd.read_csv("./data/titanic/train.csv")

# %%
f=data.isnull().sum().reset_index()

# %%
f
# Out:
#           index    0
# 0   PassengerId    0
# 1      Survived    0
# 2        Pclass    0
# 3          Name    0
# 4           Sex    0
# 5           Age  177
# 6         SibSp    0
# 7         Parch    0
# 8        Ticket    0
# 9          Fare    0
# 10        Cabin  687
# 11     Embarked    2

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum().reset_index()
# Out:
#           index  0
# 0   PassengerId  0
# 1      Survived  0
# 2        Pclass  0
# 3          Name  0
# 4           Sex  0
# 5           Age  0
# 6         SibSp  0
# 7         Parch  0
# 8        Ticket  0
# 9          Fare  0
# 10        Cabin  0
# 11     Embarked  0

# %%
data.shape
# Out:
# (183, 12)

# %%
import seaborn as sb

# %%
sb.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum().reset_index()
# Out:
#                  index      0
# 0                  res      0
# 1           MainBranch    299
# 2             Hobbyist     45
# 3                  Age  19015
# 4           Age1stCode   6561
# ..                 ...    ...
# 56  WebframeWorkedWith  22182
# 57       WelcomeChange  11778
# 58         WorkWeekHrs  23310
# 59           YearsCode   6777
# 60        YearsCodePro  18112
#
# [61 rows x 2 columns]

# %%
data.isnull().sum().reset_index()
# Out:
#           index  0
# 0   PassengerId  0
# 1      Survived  0
# 2        Pclass  0
# 3          Name  0
# 4           Sex  0
# 5           Age  0
# 6         SibSp  0
# 7         Parch  0
# 8        Ticket  0
# 9          Fare  0
# 10        Cabin  0
# 11     Embarked  0

# %%
sn.histplot(data.Age,bins=50,kde=True)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
sn.violinplot(x=data.Age)
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
sn.boxenplot(x=data.Age)
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
sn.boxplot(x=data.Age)
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
sn.catplot(x="Sex", y="Age",hue="Survived",data=data)

# %%
sn.swarmplot(x="Sex", y="Age",hue="Survived",data=data)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %%
sn.violinplot(x="Sex", y="Age",hue="Survived",data=data)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %%
sn.boxplot(x="Sex", y="Age",hue="Survived",data=data)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %%
sn.boxenplot(x="Sex", y="Age",hue="Survived",data=data)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %%
sn.stripplot(x="Sex", y="Age",hue="Survived",data=data)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %%
sn.rugplot( y="Age",hue="Survived",data=data)
# Out:
# <AxesSubplot:ylabel='Age'>

# %%
pd.crosstab(data.Pclass,data.Survived,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_dcf7d_row0_col0 {
#   background-color: #239166;
#   color: #f1f1f1;
# }
# #T_dcf7d_row0_col1, #T_dcf7d_row0_col2 {
#   background-color: #249266;
#   color: #f1f1f1;
# }
# #T_dcf7d_row1_col0, #T_dcf7d_row2_col1, #T_dcf7d_row2_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_dcf7d_row1_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_dcf7d_row1_col2 {
#   background-color: #f8fc66;
#   color: #000000;
# }
# #T_dcf7d_row2_col0 {
#   background-color: #f7fb66;
#   color: #000000;
# }
# #T_dcf7d_row3_col0, #T_dcf7d_row3_col1, #T_dcf7d_row3_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_dcf7d">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_dcf7d_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_dcf7d_level0_col1" class="col_heading level0 col1" >1</th>
# ...

# %%
pd.crosstab(data.Pclass,data.Survived).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_1a1a4_row0_col0, #T_1a1a4_row0_col1 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_1a1a4_row1_col0, #T_1a1a4_row2_col1 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_1a1a4_row1_col1 {
#   background-color: #eef666;
#   color: #000000;
# }
# #T_1a1a4_row2_col0 {
#   background-color: #f5fa66;
#   color: #000000;
# }
# </style>
# <table id="T_1a1a4">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_1a1a4_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_1a1a4_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1a1a4_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_1a1a4_row0_col0" class="data row0 col0" >52</td>
# ...

# %%
pd.crosstab(data.SibSp,data.Survived,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_5b1f1_row0_col0 {
#   background-color: #52a866;
#   color: #f1f1f1;
# }
# #T_5b1f1_row0_col1 {
#   background-color: #72b866;
#   color: #f1f1f1;
# }
# #T_5b1f1_row0_col2 {
#   background-color: #67b366;
#   color: #f1f1f1;
# }
# #T_5b1f1_row1_col0 {
#   background-color: #badc66;
#   color: #000000;
# }
# #T_5b1f1_row1_col1 {
#   background-color: #a0d066;
#   color: #000000;
# }
# #T_5b1f1_row1_col2 {
#   background-color: #a9d466;
#   color: #000000;
# }
# #T_5b1f1_row2_col0, #T_5b1f1_row3_col0, #T_5b1f1_row3_col1, #T_5b1f1_row3_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_5b1f1_row2_col1 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_5b1f1_row2_col2 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_5b1f1_row4_col0, #T_5b1f1_row4_col1, #T_5b1f1_row4_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5b1f1">
#   <thead>
#     <tr>
# ...

# %%
sn.boxenplot(x="Pclass",y="Age", hue="Survived", data=data)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %%
sn.countplot(x=data.Sex)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
sn.countplot(x=data.Survived)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sn.countplot(x=data.SibSp)
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='count'>

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   183.000000  183.000000  183.000000  183.000000  183.000000
# mean    455.366120    0.672131    1.191257   35.674426    0.464481
# std     247.052476    0.470725    0.515187   15.643866    0.644159
# min       2.000000    0.000000    1.000000    0.920000    0.000000
# 25%     263.500000    0.000000    1.000000   24.000000    0.000000
# 50%     457.000000    1.000000    1.000000   36.000000    0.000000
# 75%     676.000000    1.000000    1.000000   47.500000    1.000000
# max     890.000000    1.000000    3.000000   80.000000    3.000000
#
#             Parch        Fare
# count  183.000000  183.000000
# mean     0.475410   78.682469
# std      0.754617   76.347843
# min      0.000000    0.000000
# 25%      0.000000   29.700000
# 50%      0.000000   57.000000
# 75%      1.000000   90.000000
# max      4.000000  512.329200

# %%
data.SibSp.value_counts(normalize=True)
# Out:
# 0    0.601093
# 1    0.349727
# 2    0.032787
# 3    0.016393
# Name: SibSp, dtype: float64

# %%
data.SibSp.value_counts()
# Out:
# 0    110
# 1     64
# 2      6
# 3      3
# Name: SibSp, dtype: int64

# %%
sn.countplot(x=data.Sex,hue=data.Pclass)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
# most people were of 1st class most were

# %%
sn.countplot(x=data.Sex,hue=data.Survived)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
# female were most survived and male were 1/2 those who survived

# %%
# data.Sex.value_counts()
c=pd.crosstab(data.Embarked,[data.Survived,data.Sex,data.Pclass],margins=True).style.background_gradient(cmap='summer_r')

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
c=pd.crosstab([data.Survived,data.Sex,data.Pclass],data.Embarked,margins=True)

# %% [markdown]
# # drill down with the levels

# %%
c.xs(1)
# Out:
# Embarked        C  Q   S  All
# Sex    Pclass
# female 1       32  1  38   71
#        2        1  0   7    8
#        3        0  0   3    3
# male   1       15  0  20   35
#        2        0  0   4    4
#        3        0  0   2    2

# %%
c.xs(1).sum()
# Out:
# Embarked
# C       48
# Q        1
# S       74
# All    123
# dtype: int64

# %%
c.xs(1).min()
# Out:
# Embarked
# C      0
# Q      0
# S      2
# All    2
# dtype: int64

# %%
c.xs(1).max()
# Out:
# Embarked
# C      32
# Q       1
# S      38
# All    71
# dtype: int64

# %%
c.xs(1).xs("male").style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_77dfa_row0_col0, #T_77dfa_row0_col2, #T_77dfa_row0_col3 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_77dfa_row0_col1, #T_77dfa_row1_col0, #T_77dfa_row1_col1, #T_77dfa_row2_col0, #T_77dfa_row2_col1, #T_77dfa_row2_col2, #T_77dfa_row2_col3 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_77dfa_row1_col2 {
#   background-color: #e3f166;
#   color: #000000;
# }
# #T_77dfa_row1_col3 {
#   background-color: #f0f866;
#   color: #000000;
# }
# </style>
# <table id="T_77dfa">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Embarked</th>
#       <th id="T_77dfa_level0_col0" class="col_heading level0 col0" >C</th>
#       <th id="T_77dfa_level0_col1" class="col_heading level0 col1" >Q</th>
#       <th id="T_77dfa_level0_col2" class="col_heading level0 col2" >S</th>
#       <th id="T_77dfa_level0_col3" class="col_heading level0 col3" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
# ...

# %%
c.xs(1).xs("male").xs(1).reset_index()
# Out:
#   Embarked   1
# 0        C  15
# 1        Q   0
# 2        S  20
# 3      All  35

# %%
c.xs(1).xs("male").xs(1)
# Out:
# Embarked
# C      15
# Q       0
# S      20
# All    35
# Name: 1, dtype: int64

# %%
c.xs(1).xs("male").xs(1)["C"]
# Out:
# 15

# %%
c.xs(1).xs("male").xs(1)["S"]
# Out:
# 20

# %% [markdown]
# # comparing the things we use crosstab using drill down able indexing
# # having multiple levels and get EDA for cetagorical
